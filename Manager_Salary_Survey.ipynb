# %%
import pandas as pd
import requests

# %%
dataloc = 'D:\Data science project\Data Cleansing and Manipulating\Ask_A_Manager_Salary_Survey 2021_(Responses)_edited.xlsx'
dataset = pd.read_excel(dataloc, sheet_name = 'Edited-data')
dataset
# Out:
#                     Timestamp         Age                       Industry  \
# 0     2021-04-27 11:02:09.743       25-34   Education (Higher Education)
# 1     2021-04-27 11:02:21.562       25-34              Computing or Tech
# 2     2021-04-27 11:02:38.125       25-34  Accounting, Banking & Finance
# 3     2021-04-27 11:02:40.643       25-34                     Nonprofits
# 4     2021-04-27 11:02:41.793       25-34  Accounting, Banking & Finance
# ...                       ...         ...                            ...
# 27789 2022-05-05 13:09:04.661       35-44              Recruitment or HR
# 27790 2022-05-05 16:03:38.955       25-34                Media & Digital
# 27791 2022-05-06 11:49:35.453       35-44                Media & Digital
# 27792 2022-05-07 03:43:06.882  65 or over              Waste Management
# 27793 2022-05-09 23:03:36.481       25-34                            Law
#
#                                       Job title  \
# 0            Research and Instruction Librarian
# 1      Change & Internal Communications Manager
# 2                          Marketing Specialist
# 3                               Program Manager
# 4                            Accounting Manager
# ...                                         ...
# 27789                          Chief HR Officer
# 27790                          Training Manager
# 27791                 Associate Managing Editor
# 27792           Waste Management Representative
# 27793          Attorney recruiting coordinator
#
#                             Job title additional context  Annual salary  \
# 0                                                    NaN          55000
# 1                                                    NaN          54600
# 2                                                    NaN          34000
# 3                                                    NaN          62000
# 4                                                    NaN          60000
# ...                                                  ...            ...
# 27789                                                NaN         150000
# 27790                                                NaN          92000
# 27791  I'm pretty senior on my team but I don't manag...         113000
# 27792                                                NaN         140000
# 27793                                                NaN          60000
#
#        Additional monetary compensation The currency  \
# 0                                   0.0          USD
# 1                                4000.0          GBP
# 2                                   NaN          USD
# 3                                3000.0          USD
# 4                                7000.0          USD
# ...                                 ...          ...
# 27789                               0.0          USD
# 27790                           15000.0          USD
# 27791                             250.0          USD
# 27792                            1500.0          USD
# 27793                               NaN          USD
#
#       Income additional context                   Country State in the U.S.  \
# 0                           NaN             United States     Massachusetts
# 1                           NaN            United Kingdom               NaN
# 2                           NaN                        US         Tennessee
# 3                           NaN                       USA         Wisconsin
# 4                           NaN                        US    South Carolina
# ...                         ...                       ...               ...
# 27789                       NaN             United States              Utah
# 27790                       NaN  United States of America          New York
# 27791                       NaN                       USA          New York
# 27792                       NaN                       USA        Washington
# 27793                       NaN             United states           Arizona
#
#                 City overall years of professional work experience  \
# 0             Boston                                     5-7 years
# 1          Cambridge                                  8 - 10 years
# 2        Chattanooga                                   2 - 4 years
# 3          Milwaukee                                  8 - 10 years
# 4         Greenville                                  8 - 10 years
# ...              ...                                           ...
# 27789         Layton                                 11 - 20 years
# 27790  New York City                                     5-7 years
# 27791       New York                                 11 - 20 years
# 27792       Richland                              41 years or more
# 27793        Phoenix                                  8 - 10 years
#
#       Years of professional work experience in field  \
# 0                                          5-7 years
# 1                                          5-7 years
# 2                                        2 - 4 years
# 3                                          5-7 years
# 4                                          5-7 years
# ...                                              ...
# 27789                                   8 - 10 years
# 27790                                      5-7 years
# 27791                                   8 - 10 years
# 27792                                  11 - 20 years
# 27793                                 1 year or less
#
#       Highest level of education      Gender                            Race
# 0                Master's degree       Woman                           White
# 1                 College degree  Non-binary                           White
# 2                 College degree       Woman                           White
# 3                 College degree       Woman                           White
# 4                 College degree       Woman                           White
# ...                          ...         ...                             ...
# 27789             College degree       Woman                           White
# 27790             College degree       Woman  Asian or Asian American, White
# 27791            Master's degree       Woman                           White
# 27792            Master's degree       Woman                           White
# 27793               Some college       Woman                           White
#
# [27794 rows x 17 columns]

# %%
data_modified = dataset.copy()

# %%
data_modified
# Out:
#                     Timestamp         Age                       Industry  \
# 0     2021-04-27 11:02:09.743       25-34   Education (Higher Education)
# 1     2021-04-27 11:02:21.562       25-34              Computing or Tech
# 2     2021-04-27 11:02:38.125       25-34  Accounting, Banking & Finance
# 3     2021-04-27 11:02:40.643       25-34                     Nonprofits
# 4     2021-04-27 11:02:41.793       25-34  Accounting, Banking & Finance
# ...                       ...         ...                            ...
# 27789 2022-05-05 13:09:04.661       35-44              Recruitment or HR
# 27790 2022-05-05 16:03:38.955       25-34                Media & Digital
# 27791 2022-05-06 11:49:35.453       35-44                Media & Digital
# 27792 2022-05-07 03:43:06.882  65 or over              Waste Management
# 27793 2022-05-09 23:03:36.481       25-34                            Law
#
#                                       Job title  \
# 0            Research and Instruction Librarian
# 1      Change & Internal Communications Manager
# 2                          Marketing Specialist
# 3                               Program Manager
# 4                            Accounting Manager
# ...                                         ...
# 27789                          Chief HR Officer
# 27790                          Training Manager
# 27791                 Associate Managing Editor
# 27792           Waste Management Representative
# 27793          Attorney recruiting coordinator
#
#                             Job title additional context  Annual salary  \
# 0                                                    NaN          55000
# 1                                                    NaN          54600
# 2                                                    NaN          34000
# 3                                                    NaN          62000
# 4                                                    NaN          60000
# ...                                                  ...            ...
# 27789                                                NaN         150000
# 27790                                                NaN          92000
# 27791  I'm pretty senior on my team but I don't manag...         113000
# 27792                                                NaN         140000
# 27793                                                NaN          60000
#
#        Additional monetary compensation The currency  \
# 0                                   0.0          USD
# 1                                4000.0          GBP
# 2                                   NaN          USD
# 3                                3000.0          USD
# 4                                7000.0          USD
# ...                                 ...          ...
# 27789                               0.0          USD
# 27790                           15000.0          USD
# 27791                             250.0          USD
# 27792                            1500.0          USD
# 27793                               NaN          USD
#
#       Income additional context                   Country State in the U.S.  \
# 0                           NaN             United States     Massachusetts
# 1                           NaN            United Kingdom               NaN
# 2                           NaN                        US         Tennessee
# 3                           NaN                       USA         Wisconsin
# 4                           NaN                        US    South Carolina
# ...                         ...                       ...               ...
# 27789                       NaN             United States              Utah
# 27790                       NaN  United States of America          New York
# 27791                       NaN                       USA          New York
# 27792                       NaN                       USA        Washington
# 27793                       NaN             United states           Arizona
#
#                 City overall years of professional work experience  \
# 0             Boston                                     5-7 years
# 1          Cambridge                                  8 - 10 years
# 2        Chattanooga                                   2 - 4 years
# 3          Milwaukee                                  8 - 10 years
# 4         Greenville                                  8 - 10 years
# ...              ...                                           ...
# 27789         Layton                                 11 - 20 years
# 27790  New York City                                     5-7 years
# 27791       New York                                 11 - 20 years
# 27792       Richland                              41 years or more
# 27793        Phoenix                                  8 - 10 years
#
#       Years of professional work experience in field  \
# 0                                          5-7 years
# 1                                          5-7 years
# 2                                        2 - 4 years
# 3                                          5-7 years
# 4                                          5-7 years
# ...                                              ...
# 27789                                   8 - 10 years
# 27790                                      5-7 years
# 27791                                   8 - 10 years
# 27792                                  11 - 20 years
# 27793                                 1 year or less
#
#       Highest level of education      Gender                            Race
# 0                Master's degree       Woman                           White
# 1                 College degree  Non-binary                           White
# 2                 College degree       Woman                           White
# 3                 College degree       Woman                           White
# 4                 College degree       Woman                           White
# ...                          ...         ...                             ...
# 27789             College degree       Woman                           White
# 27790             College degree       Woman  Asian or Asian American, White
# 27791            Master's degree       Woman                           White
# 27792            Master's degree       Woman                           White
# 27793               Some college       Woman                           White
#
# [27794 rows x 17 columns]

# %% [markdown]
# # Fill in Na value

# %%
data_modified.isna().sum()
# Out:
# Timestamp                                             0
# Age                                                   0
# Industry                                             70
# Job title                                             0
# Job title additional context                      20603
# Annual salary                                         0
# Additional monetary compensation                   7198
# The currency                                          0
# Income additional context                         24772
# Country                                               0
# State in the U.S.                                  4940
# City                                                 75
# overall years of professional work experience         0
# Years of professional work experience in field        0
# Highest level of education                          210
# Gender                                              165
# Race                                                164
# dtype: int64

# %%
data_modified.drop(columns = 'Race', inplace = True)

# %%
data_modified.dropna(subset = ['Industry'], inplace = True)

# %%
data_modified['Job title additional context'].fillna(value = 'no additional context', inplace= True)

# %%
data_modified['Additional monetary compensation'].fillna(0, inplace = True)

# %%
data_modified['Income additional context'].fillna(value = 'no additional context', inplace= True)

# %%
data_modified['State in the U.S.'].fillna(value = 'outside U.S.' , inplace = True)

# %%
data_modified.fillna(value = 'no information' , inplace = True)

# %%
data_modified.isna().sum()
# Out:
# Timestamp                                         0
# Age                                               0
# Industry                                          0
# Job title                                         0
# Job title additional context                      0
# Annual salary                                     0
# Additional monetary compensation                  0
# The currency                                      0
# Income additional context                         0
# Country                                           0
# State in the U.S.                                 0
# City                                              0
# overall years of professional work experience     0
# Years of professional work experience in field    0
# Highest level of education                        0
# Gender                                            0
# dtype: int64

# %%
data_modified
# Out:
#                     Timestamp         Age                       Industry  \
# 0     2021-04-27 11:02:09.743       25-34   Education (Higher Education)
# 1     2021-04-27 11:02:21.562       25-34              Computing or Tech
# 2     2021-04-27 11:02:38.125       25-34  Accounting, Banking & Finance
# 3     2021-04-27 11:02:40.643       25-34                     Nonprofits
# 4     2021-04-27 11:02:41.793       25-34  Accounting, Banking & Finance
# ...                       ...         ...                            ...
# 27789 2022-05-05 13:09:04.661       35-44              Recruitment or HR
# 27790 2022-05-05 16:03:38.955       25-34                Media & Digital
# 27791 2022-05-06 11:49:35.453       35-44                Media & Digital
# 27792 2022-05-07 03:43:06.882  65 or over              Waste Management
# 27793 2022-05-09 23:03:36.481       25-34                            Law
#
#                                       Job title  \
# 0            Research and Instruction Librarian
# 1      Change & Internal Communications Manager
# 2                          Marketing Specialist
# 3                               Program Manager
# 4                            Accounting Manager
# ...                                         ...
# 27789                          Chief HR Officer
# 27790                          Training Manager
# 27791                 Associate Managing Editor
# 27792           Waste Management Representative
# 27793          Attorney recruiting coordinator
#
#                             Job title additional context  Annual salary  \
# 0                                  no additional context          55000
# 1                                  no additional context          54600
# 2                                  no additional context          34000
# 3                                  no additional context          62000
# 4                                  no additional context          60000
# ...                                                  ...            ...
# 27789                              no additional context         150000
# 27790                              no additional context          92000
# 27791  I'm pretty senior on my team but I don't manag...         113000
# 27792                              no additional context         140000
# 27793                              no additional context          60000
#
#        Additional monetary compensation The currency  \
# 0                                   0.0          USD
# 1                                4000.0          GBP
# 2                                   0.0          USD
# 3                                3000.0          USD
# 4                                7000.0          USD
# ...                                 ...          ...
# 27789                               0.0          USD
# 27790                           15000.0          USD
# 27791                             250.0          USD
# 27792                            1500.0          USD
# 27793                               0.0          USD
#
#       Income additional context                   Country State in the U.S.  \
# 0         no additional context             United States     Massachusetts
# 1         no additional context            United Kingdom      outside U.S.
# 2         no additional context                        US         Tennessee
# 3         no additional context                       USA         Wisconsin
# 4         no additional context                        US    South Carolina
# ...                         ...                       ...               ...
# 27789     no additional context             United States              Utah
# 27790     no additional context  United States of America          New York
# 27791     no additional context                       USA          New York
# 27792     no additional context                       USA        Washington
# 27793     no additional context             United states           Arizona
#
#                 City overall years of professional work experience  \
# 0             Boston                                     5-7 years
# 1          Cambridge                                  8 - 10 years
# 2        Chattanooga                                   2 - 4 years
# 3          Milwaukee                                  8 - 10 years
# 4         Greenville                                  8 - 10 years
# ...              ...                                           ...
# 27789         Layton                                 11 - 20 years
# 27790  New York City                                     5-7 years
# 27791       New York                                 11 - 20 years
# 27792       Richland                              41 years or more
# 27793        Phoenix                                  8 - 10 years
#
#       Years of professional work experience in field  \
# 0                                          5-7 years
# 1                                          5-7 years
# 2                                        2 - 4 years
# 3                                          5-7 years
# 4                                          5-7 years
# ...                                              ...
# 27789                                   8 - 10 years
# 27790                                      5-7 years
# 27791                                   8 - 10 years
# 27792                                  11 - 20 years
# 27793                                 1 year or less
#
#       Highest level of education      Gender
# 0                Master's degree       Woman
# 1                 College degree  Non-binary
# 2                 College degree       Woman
# 3                 College degree       Woman
# 4                 College degree       Woman
# ...                          ...         ...
# 27789             College degree       Woman
# 27790             College degree       Woman
# 27791            Master's degree       Woman
# 27792            Master's degree       Woman
# 27793               Some college       Woman
#
# [27724 rows x 16 columns]

# %% [markdown]
# # Replacing incorrect currency code

# %%
pd.set_option('display.max_rows', None)
data_modified['The currency'].value_counts()
# Out:
# USD                         23126
# CAD                          1654
# GBP                          1573
# EUR                           627
# AUD/NZD                       496
# CHF                            38
# SEK                            38
# JPY                            23
# ZAR                            14
# INR                             9
# MYR                             8
# NOK                             8
# SGD                             7
# DKK                             7
# BRL                             6
# HKD                             4
# 0                               4
# CZK                             4
# PLN                             3
# AUD                             3
# NTD                             2
# KRW                             2
# CNY                             2
# ILS                             2
# THB                             2
# MXN                             2
# ARS                             2
# Dkk                             2
# NZD                             2
# PhP (Philippine Peso)           1
# Israeli Shekels                 1
# Argentinian peso (ARS)          1
# Equity                          1
# PHP                             1
# Ils                             1
# SAR                             1
# dkk                             1
# croatian kuna                   1
# Thai Baht                       1
# THAI  BAHT                      1
# Mexican Pesos                   1
# SGD                             1
# Euro                            1
# Korean Won                      1
# RM                              1
# Danish Kroner                   1
# INR (Indian Rupee)              1
# Philippine peso (PHP)           1
# Philippine Pesos                1
# Argentine Peso                  1
# IDR                             1
# Australian Dollars              1
# Czk                             1
# Polish Złoty                    1
# LKR                             1
# Peso Argentino                  1
# BR$                             1
# TTD                             1
# Indian rupees                   1
# BRL (R$)                        1
# Mexican pesos                   1
# Bdt                             1
# American Dollars                1
# Php                             1
# PLN (Polish zloty)              1
# czech crowns                    1
# TRY                             1
# Norwegian kroner (NOK)          1
# ILS/NIS                         1
# US Dollar                       1
# NIS (new Israeli shekel)        1
# RMB (chinese yuan)              1
# Taiwanese dollars               1
# Philippine Peso                 1
# KRW (Korean Won)                1
# IDR                             1
# Sgd                             1
# Nok                             1
# ILS (Shekel)                    1
# DKK                             1
# China RMB                       1
# AUD Australian                  1
# PLN (Zwoty)                     1
# Name: The currency, dtype: int64

# %%
data_modified['The currency'].replace(to_replace = ['AUD Australian ','Australian Dollars ','AUD/NZD'], value = 'AUD',inplace = True)

# %%
data_modified['The currency'].replace(['American Dollars','US Dollar'],'USD',inplace = True)

# %%
data_modified['The currency'].replace(['Philippine Pesos','PhP (Philippine Peso)','Philippine Peso','Php','Philippine peso (PHP)'],'PHP',inplace = True)

# %%
data_modified['The currency'].replace(['INR (Indian Rupee)','Indian rupees'],'INR',inplace = True)

# %%
data_modified['The currency'].replace(['Argentinian peso (ARS)','Argentine Peso','Peso Argentino'],'ARS',inplace = True)

# %%
data_modified['The currency'].replace(['Euro'],'EUR',inplace = True)

# %%
data_modified['The currency'].replace(['Israeli Shekels','Ils','ILS/NIS','NIS (new Israeli shekel)','ILS (Shekel)'],'ILS',inplace = True)

# %%
data_modified['The currency'].replace(['Dkk','dkk','Danish Kroner','DKK '],'DKK',inplace = True)

# %%
data_modified['The currency'].replace(['Mexican Pesos','Mexican pesos'],'MXN',inplace = True)

# %%
data_modified['The currency'].replace(['China RMB','RMB (chinese yuan)','RMB'],'CNY',inplace = True)

# %%
data_modified['The currency'].replace(['THAI  BAHT','Thai Baht '],'THB',inplace = True)

# %%
data_modified['The currency'].replace(['PLN (Zwoty)','PLN (Polish zloty)','Polish Złoty'],'PLN',inplace = True)

# %%
data_modified['The currency'].replace(['Korean Won ','KRW (Korean Won)'],'KRW',inplace = True)

# %%
data_modified['The currency'].replace(['Taiwanese dollars','NTD'],'TWD',inplace = True)

# %%
data_modified['The currency'].replace(['Norwegian kroner (NOK)','Nok'],'NOK',inplace = True)

# %%
data_modified['The currency'].replace(['croatian kuna'],'HRK',inplace = True)

# %%
data_modified['The currency'].replace(['IDR '],'IDR',inplace = True)

# %%
data_modified['The currency'].replace(['Czk','czech crowns'],'CZK',inplace = True)

# %%
data_modified['The currency'].replace(['Sgd','SGD '],'SGD',inplace = True)

# %%
data_modified['The currency'].replace(['BR$','BRL (R$)'],'BRL',inplace = True)

# %%
data_modified['The currency'].replace(['Bdt'],'BDT',inplace = True)

# %%
data_modified['The currency'].replace(['RM'],'MYR',inplace = True)

# %%
data_modified['The currency'].replace([0, 'Equity'], 'to_drop', inplace =True)

# %%
data_modified[data_modified['The currency'] == 'to_drop']
# Out:
#                     Timestamp    Age                              Industry  \
# 9344  2021-04-27 17:44:21.776  45-54  Government and Public Administration
# 14915 2021-04-28 15:43:39.025  25-34           Marketing, Advertising & PR
# 18843 2021-04-29 03:50:24.400  18-24                           Health care
# 18882 2021-04-29 04:30:05.127  25-34                     Computing or Tech
# 18904 2021-04-29 04:59:14.128  45-54                               Mining
#
#                         Job title Job title additional context  Annual salary  \
# 9344      Contracts Administrator        no additional context          76000
# 14915  Marketing Content Creator         no additional context          65000
# 18843      Microbiologist officer       Lab manager kinda work          48000
# 18882                Data Analyst        no additional context          97000
# 18904             Office manager         no additional context          55140
#
#        Additional monetary compensation The currency  \
# 9344                                0.0      to_drop
# 14915                            5000.0      to_drop
# 18843                               0.0      to_drop
# 18882                               0.0      to_drop
# 18904                               0.0      to_drop
#
#       Income additional context        Country State in the U.S.  \
# 9344      no additional context  United States        California
# 14915     no additional context  United States          New York
# 18843                        RM       Malaysia      outside U.S.
# 18882     no additional context       Malaysia      outside U.S.
# 18904     no additional context            USA            Nevada
#
#                City overall years of professional work experience  \
# 9344   Berkeley, CA                                 11 - 20 years
# 14915      Brooklyn                                  8 - 10 years
# 18843         Tawau                                1 year or less
# 18882    Georgetown                                   2 - 4 years
# 18904          Elko                                 11 - 20 years
#
#       Years of professional work experience in field  \
# 9344                                       5-7 years
# 14915                                    2 - 4 years
# 18843                                 1 year or less
# 18882                                    2 - 4 years
# 18904                                  11 - 20 years
#
#       Highest level of education      Gender
# 9344                Some college       Woman
# 14915             College degree       Woman
# 18843               Some college         Man
# 18882             College degree  Non-binary
# 18904               Some college       Woman

# %%
data_modified.drop([9344,14915,18843,18882,18904], axis = 0, inplace = True)

# %%
data_modified['The currency'].value_counts()
# Out:
# USD    23128
# CAD     1654
# GBP     1573
# EUR      628
# AUD      501
# CHF       38
# SEK       38
# JPY       23
# ZAR       14
# DKK       12
# INR       11
# NOK       10
# SGD        9
# MYR        9
# BRL        8
# ILS        7
# PHP        6
# PLN        6
# CZK        6
# ARS        5
# MXN        4
# CNY        4
# HKD        4
# KRW        4
# THB        4
# TWD        3
# IDR        2
# NZD        2
# BDT        1
# TRY        1
# TTD        1
# LKR        1
# SAR        1
# HRK        1
# Name: The currency, dtype: int64

# %%
url = 'https://api.exchangerate.host/latest'
response = requests.get(url,params = {'base':'USD'})
exchange_rate = response.json()['rates']
exchange_rate
# Out:
# {'AED': 3.672929,
#  'AFN': 90.908146,
#  'ALL': 113.355941,
#  'AMD': 461.245218,
#  'ANG': 1.803837,
#  'AOA': 415.358841,
#  'ARS': 118.316608,
#  'AUD': 1.410754,
#  'AWG': 1.800927,
#  'AZN': 1.700821,
#  'BAM': 1.848935,
#  'BBD': 2.000288,
#  'BDT': 87.524717,
#  'BGN': 1.852126,
#  'BHD': 0.377412,
#  'BIF': 2056.473049,
#  'BMD': 1.000533,
#  'BND': 1.378909,
#  'BOB': 6.889648,
#  'BRL': 4.881119,
#  'BSD': 1.000625,
#  'BTC': 3.3e-05,
#  'BTN': 77.614206,
#  'BWP': 12.113413,
#  'BYN': 3.377835,
#  'BZD': 2.017317,
#  'CAD': 1.280533,
#  'CDF': 2001.153179,
#  'CHF': 0.972673,
#  'CLF': 0.030777,
#  'CLP': 836.757644,
#  'CNH': 6.693958,
#  'CNY': 6.684552,
#  'COP': 4053.842111,
#  'CRC': 671.656844,
#  'CUC': 1.000602,
#  'CUP': 25.747457,
#  'CVE': 104.641115,
#  'CZK': 23.226842,
#  'DJF': 178.118362,
#  'DKK': 7.025457,
#  'DOP': 55.255617,
#  'DZD': 145.560223,
#  'EGP': 18.230419,
#  'ERN': 14.999603,
#  'ETB': 51.944202,
#  'EUR': 0.944886,
#  'FJD': 2.186205,
#  'FKP': 0.797679,
#  'GBP': 0.79755,
#  'GEL': 2.905626,
#  'GGP': 0.79733,
#  'GHS': 7.780833,
#  'GIP': 0.797321,
#  'GMD': 54.145472,
#  'GNF': 8845.149762,
#  'GTQ': 7.678824,
#  'GYD': 209.33984,
#  'HKD': 7.848712,
#  'HNL': 24.578437,
#  'HRK': 7.119856,
#  'HTG': 112.071378,
#  'HUF': 362.25143,
#  'IDR': 14664.635108,
#  'ILS': 3.351005,
#  'IMP': 0.796961,
#  'INR': 77.604992,
#  'IQD': 1460.411354,
#  'IRR': 42296.062085,
#  'ISK': 130.948589,
#  'JEP': 0.797318,
#  'JMD': 154.638038,
#  'JOD': 0.709384,
#  'JPY': 127.479767,
#  'KES': 116.489002,
#  'KGS': 79.934443,
#  'KHR': 4063.500861,
#  'KMF': 466.906448,
#  'KPW': 899.917096,
#  'KRW': 1268.465503,
#  'KWD': 0.306436,
#  'KYD': 0.834432,
#  'KZT': 426.011988,
#  'LAK': 13265.622998,
#  'LBP': 1513.090079,
#  'LKR': 355.211072,
#  'LRD': 152.486859,
#  'LSL': 15.845295,
#  'LYD': 4.812495,
#  'MAD': 10.019613,
#  'MDL': 19.163059,
#  'MGA': 4044.524807,
#  'MKD': 58.224881,
#  'MMK': 1852.441493,
#  'MNT': 3102.06175,
#  'MOP': 8.087492,
#  'MRU': 36.5133,
#  'MUR': 43.096223,
#  'MVR': 15.424417,
#  'MWK': 817.369428,
#  'MXN': 19.861092,
#  'MYR': 4.391642,
#  'MZN': 63.844884,
#  'NAD': 15.919255,
#  'NGN': 415.25835,
#  'NIO': 35.85822,
#  'NOK': 9.686255,
#  'NPR': 124.163787,
#  'NZD': 1.549233,
#  'OMR': 0.384471,
#  'PAB': 1.000214,
#  'PEN': 3.738327,
#  'PGK': 3.527081,
#  'PHP': 52.219164,
#  'PKR': 201.227333,
#  'PLN': 4.370459,
#  'PYG': 6842.918753,
#  'QAR': 3.655658,
#  'RON': 4.672653,
#  'RSD': 111.100142,
#  'RUB': 60.019915,
#  'RWF': 1027.621633,
#  'SAR': 3.751513,
#  'SBD': 8.123855,
#  'SCR': 12.945328,
#  'SDG': 449.373347,
#  'SEK': 9.903945,
#  'SGD': 1.377178,
#  'SHP': 0.797325,
#  'SLL': 12887.700343,
#  'SOS': 578.826848,
#  'SRD': 21.007185,
#  'SSP': 130.248203,
#  'STD': 22133.029914,
#  'STN': 23.408519,
#  'SVC': 8.755649,
#  'SYP': 2512.297001,
#  'SZL': 15.842935,
#  'THB': 34.307244,
#  'TJS': 12.51548,
#  'TMT': 3.500389,
#  'TND': 3.060909,
#  'TOP': 2.322192,
#  'TRY': 15.905647,
#  'TTD': 6.794112,
#  'TWD': 29.657548,
#  'TZS': 2328.190114,
#  'UAH': 29.559195,
#  'UGX': 3647.26302,
#  'USD': 1,
#  'UYU': 40.342035,
#  'UZS': 11101.729169,
#  'VES': 4.825766,
#  'VND': 23162.082572,
#  'VUV': 115.699364,
#  'WST': 2.635455,
#  'XAF': 619.284985,
#  'XAG': 0.045534,
#  'XAU': 0.001459,
#  'XCD': 2.702134,
#  'XDR': 0.729216,
#  'XOF': 619.284917,
#  'XPD': 0.001714,
#  'XPF': 112.660848,
#  'XPT': 0.001062,
#  'YER': 250.227181,
#  'ZAR': 15.804862,
#  'ZMW': 17.044052,
#  'ZWL': 321.970809}

# %%
rates = pd.DataFrame.from_dict(exchange_rate, orient ='index', columns = ['Exchange_rate'])
rates.index.name = 'Currency code'
rates
# Out:
#                Exchange_rate
# Currency code
# AED                 3.672929
# AFN                90.908146
# ALL               113.355941
# AMD               461.245218
# ANG                 1.803837
# AOA               415.358841
# ARS               118.316608
# AUD                 1.410754
# AWG                 1.800927
# AZN                 1.700821
# BAM                 1.848935
# BBD                 2.000288
# BDT                87.524717
# BGN                 1.852126
# BHD                 0.377412
# BIF              2056.473049
# BMD                 1.000533
# BND                 1.378909
# BOB                 6.889648
# BRL                 4.881119
# BSD                 1.000625
# BTC                 0.000033
# BTN                77.614206
# BWP                12.113413
# BYN                 3.377835
# BZD                 2.017317
# CAD                 1.280533
# CDF              2001.153179
# CHF                 0.972673
# CLF                 0.030777
# CLP               836.757644
# CNH                 6.693958
# CNY                 6.684552
# COP              4053.842111
# CRC               671.656844
# CUC                 1.000602
# CUP                25.747457
# CVE               104.641115
# CZK                23.226842
# DJF               178.118362
# DKK                 7.025457
# DOP                55.255617
# DZD               145.560223
# EGP                18.230419
# ERN                14.999603
# ETB                51.944202
# EUR                 0.944886
# FJD                 2.186205
# FKP                 0.797679
# GBP                 0.797550
# GEL                 2.905626
# GGP                 0.797330
# GHS                 7.780833
# GIP                 0.797321
# GMD                54.145472
# GNF              8845.149762
# GTQ                 7.678824
# GYD               209.339840
# HKD                 7.848712
# HNL                24.578437
# HRK                 7.119856
# HTG               112.071378
# HUF               362.251430
# IDR             14664.635108
# ILS                 3.351005
# IMP                 0.796961
# INR                77.604992
# IQD              1460.411354
# IRR             42296.062085
# ISK               130.948589
# JEP                 0.797318
# JMD               154.638038
# JOD                 0.709384
# JPY               127.479767
# KES               116.489002
# KGS                79.934443
# KHR              4063.500861
# KMF               466.906448
# KPW               899.917096
# KRW              1268.465503
# KWD                 0.306436
# KYD                 0.834432
# KZT               426.011988
# LAK             13265.622998
# LBP              1513.090079
# LKR               355.211072
# LRD               152.486859
# LSL                15.845295
# LYD                 4.812495
# MAD                10.019613
# MDL                19.163059
# MGA              4044.524807
# MKD                58.224881
# MMK              1852.441493
# MNT              3102.061750
# MOP                 8.087492
# MRU                36.513300
# MUR                43.096223
# MVR                15.424417
# MWK               817.369428
# MXN                19.861092
# MYR                 4.391642
# MZN                63.844884
# NAD                15.919255
# NGN               415.258350
# NIO                35.858220
# NOK                 9.686255
# NPR               124.163787
# NZD                 1.549233
# OMR                 0.384471
# PAB                 1.000214
# PEN                 3.738327
# PGK                 3.527081
# PHP                52.219164
# PKR               201.227333
# PLN                 4.370459
# PYG              6842.918753
# QAR                 3.655658
# RON                 4.672653
# RSD               111.100142
# RUB                60.019915
# RWF              1027.621633
# SAR                 3.751513
# SBD                 8.123855
# SCR                12.945328
# SDG               449.373347
# SEK                 9.903945
# SGD                 1.377178
# SHP                 0.797325
# SLL             12887.700343
# SOS               578.826848
# SRD                21.007185
# SSP               130.248203
# STD             22133.029914
# STN                23.408519
# SVC                 8.755649
# SYP              2512.297001
# SZL                15.842935
# THB                34.307244
# TJS                12.515480
# TMT                 3.500389
# TND                 3.060909
# TOP                 2.322192
# TRY                15.905647
# TTD                 6.794112
# TWD                29.657548
# TZS              2328.190114
# UAH                29.559195
# UGX              3647.263020
# USD                 1.000000
# UYU                40.342035
# UZS             11101.729169
# VES                 4.825766
# VND             23162.082572
# VUV               115.699364
# WST                 2.635455
# XAF               619.284985
# XAG                 0.045534
# XAU                 0.001459
# XCD                 2.702134
# XDR                 0.729216
# XOF               619.284917
# XPD                 0.001714
# XPF               112.660848
# XPT                 0.001062
# YER               250.227181
# ZAR                15.804862
# ZMW                17.044052
# ZWL               321.970809

# %%
list(data_modified.columns)
# Out:
# ['Timestamp',
#  'Age',
#  'Industry',
#  'Job title',
#  'Job title additional context',
#  'Annual salary',
#  'Additional monetary compensation',
#  'The currency',
#  'Income additional context',
#  'Country',
#  'State in the U.S.',
#  'City',
#  'overall years of professional work experience',
#  'Years of professional work experience in field',
#  'Highest level of education',
#  'Gender']

# %%
real_currency = data_modified[['Annual salary','Additional monetary compensation','The currency']]
currency= real_currency.merge(rates ,how = 'left', left_on = 'The currency', right_index = True)

# %%
currency['annual salary in USD'] = currency['Annual salary']/currency['Exchange_rate']
currency['annual salary in USD'] = currency['annual salary in USD'].astype(int)

# %%
currency['Additional monetary compensation in USD'] = currency['Additional monetary compensation']/currency['Exchange_rate']
currency['Additional monetary compensation in USD'] = currency['Additional monetary compensation in USD'].astype(int)
salary_in_usd = currency[['The currency','annual salary in USD','Additional monetary compensation in USD']]

# %%
salary_in_usd.head()
# Out:
#   The currency  annual salary in USD  Additional monetary compensation in USD
# 0          USD                 55000                                        0
# 1          GBP                 68459                                     5015
# 2          USD                 34000                                        0
# 3          USD                 62000                                     3000
# 4          USD                 60000                                     7000

# %%
salary_in_usd.count()
# Out:
# The currency                               27719
# annual salary in USD                       27719
# Additional monetary compensation in USD    27719
# dtype: int64

# %%
data_modified.count()
# Out:
# Timestamp                                         27719
# Age                                               27719
# Industry                                          27719
# Job title                                         27719
# Job title additional context                      27719
# Annual salary                                     27719
# Additional monetary compensation                  27719
# The currency                                      27719
# Income additional context                         27719
# Country                                           27719
# State in the U.S.                                 27719
# City                                              27719
# overall years of professional work experience     27719
# Years of professional work experience in field    27719
# Highest level of education                        27719
# Gender                                            27719
# dtype: int64

# %%
merged_data = data_modified.join
# Out:
#                 Timestamp    Age                      Industry  \
# 0 2021-04-27 11:02:09.743  25-34  Education (Higher Education)
# 1 2021-04-27 11:02:09.743  25-34  Education (Higher Education)
# 2 2021-04-27 11:02:09.743  25-34  Education (Higher Education)
# 3 2021-04-27 11:02:09.743  25-34  Education (Higher Education)
# 4 2021-04-27 11:02:09.743  25-34  Education (Higher Education)
#
#                             Job title Job title additional context  \
# 0  Research and Instruction Librarian        no additional context
# 1  Research and Instruction Librarian        no additional context
# 2  Research and Instruction Librarian        no additional context
# 3  Research and Instruction Librarian        no additional context
# 4  Research and Instruction Librarian        no additional context
#
#    Annual salary  Additional monetary compensation The currency_x  \
# 0          55000                               0.0            USD
# 1          55000                               0.0            USD
# 2          55000                               0.0            USD
# 3          55000                               0.0            USD
# 4          55000                               0.0            USD
#
#   Income additional context        Country State in the U.S.    City  \
# 0     no additional context  United States     Massachusetts  Boston
# 1     no additional context  United States     Massachusetts  Boston
# 2     no additional context  United States     Massachusetts  Boston
# 3     no additional context  United States     Massachusetts  Boston
# 4     no additional context  United States     Massachusetts  Boston
#
#   overall years of professional work experience  \
# 0                                     5-7 years
# 1                                     5-7 years
# 2                                     5-7 years
# 3                                     5-7 years
# 4                                     5-7 years
#
#   Years of professional work experience in field Highest level of education  \
# 0                                      5-7 years            Master's degree
# 1                                      5-7 years            Master's degree
# 2                                      5-7 years            Master's degree
# 3                                      5-7 years            Master's degree
# 4                                      5-7 years            Master's degree
#
#   Gender The currency_y  annual salary in USD  \
# 0  Woman            USD               55000.0
# 1  Woman            USD               55000.0
# 2  Woman            USD               55000.0
# 3  Woman            USD               55000.0
# 4  Woman            USD               55000.0
#
#    Additional monetary compensation in USD
# 0                                      0.0
# 1                                      0.0
# 2                                      0.0
# 3                                   2500.0
# 4                                   5000.0
